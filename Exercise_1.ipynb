# %%
from typing import Dict, TypedDict
from langgraph.graph import StateGraph

# %%
# Creates an AgentState - shared data structure for the agent to store and retrieve information
class AgentState(TypedDict):
    message : str

def compliment_node(state: AgentState) -> AgentState:
    """Simple node that adds a personalized compliment to the state."""
    state['message'] =  state['message'] + ", you are doing an amazing job learning LangGraph!"
    return state

# %%
graph= StateGraph(AgentState)
graph.add_node("compliment", compliment_node)
graph.set_entry_point("compliment")
graph.set_finish_point("compliment")

app = graph.compile()

# %%
from IPython.display import Image, display
display(Image(app.get_graph().draw_mermaid_png()))

# %%
results = app.invoke({"message": "Wageesha"})

# %%
results["message"]
# Out:
# 'Wageesha, you are doing an amazing job learning LangGraph!'
