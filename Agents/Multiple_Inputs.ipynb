# %%
from typing import List, TypedDict
from langgraph.graph import StateGraph

# %%
class AgentState(TypedDict):
    values: List[int]
    name: str
    results: str

# %%
def process_node(state: AgentState) -> AgentState:
    """Node that handles different types of inputs."""
    state["results"] = f"Hi there {state['name']}, the sum of your values is {sum(state['values'])}."
    return state

# %%
graph = StateGraph(AgentState)
graph.add_node("processor", process_node)
graph.set_entry_point("processor")
graph.set_finish_point("processor")
app = graph.compile()

# %%
from IPython.display import Image, display
display(Image(app.get_graph().draw_mermaid_png()))

# %%
answers = app.invoke({"values": [1, 2, 3], "name": "ageesha"})

# %%
print(answers)
# Out:
# {'values': [1, 2, 3], 'name': 'Wageesha', 'results': 'Hi there Wageesha, the sum of your values is 6.'}
